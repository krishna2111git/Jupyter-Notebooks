# %%
import seaborn as sb
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sb.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df['weekend']=df.day.isin(['Sun','Sat'])
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  weekend
# 0         16.99  1.01  Female     No   Sun  Dinner     2     True
# 1         10.34  1.66    Male     No   Sun  Dinner     3     True
# 2         21.01  3.50    Male     No   Sun  Dinner     3     True
# 3         23.68  3.31    Male     No   Sun  Dinner     2     True
# 4         24.59  3.61  Female     No   Sun  Dinner     4     True
# ..          ...   ...     ...    ...   ...     ...   ...      ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3     True
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2     True
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2     True
# 242       17.82  1.75    Male     No   Sat  Dinner     2     True
# 243       18.78  3.00  Female     No  Thur  Dinner     2    False
#
# [244 rows x 8 columns]

# %%
sb.jointplot(x="tip" , y='total_bill', data=df,)

# %%
sb.pairplot(df)
# Out:
# D:\Program Files\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.pairplot(df, diag_kind='kde')
# Out:
# D:\Program Files\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.pairplot(df, kind='hist', hue='weekend')
# Out:
# D:\Program Files\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
data = np.random.normal(loc=0, scale=1, size=1000)

# Create a KDE plot
sb.kdeplot(data)
# Out:
# <Axes: ylabel='Density'>

# %%
sb.displot(df.total_bill, kind='hist')
# Out:
# D:\Program Files\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.displot(df.total_bill, kind='kde')
# Out:
# D:\Program Files\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sb.countplot(x='sex', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sb.barplot(x='sex', y='total_bill', data=df)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sb.boxplot(x='total_bill', y='day', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sb.boxplot(df)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(100,80))

# %%
sb.violinplot(data=df, x='total_bill', y='day')
# Out:
# <Axes: xlabel='total_bill', ylabel='day'>

# %%
sb.kdeplot(x='total_bill', data=df)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sb.kdeplot(data=df, x='total_bill', y='tip')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>
